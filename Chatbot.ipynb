# %% [markdown]
# <a href="https://colab.research.google.com/github/archanak06102007-code/chatbot.py/blob/main/Chatbot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install groq
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.7/143.7 kB 2.5 MB/s eta 0:00:00
# ...

# %%
from groq import Groq
from google.colab import userdata

# Assign the API key fetched from Colab secrets to the API_KEY variable
API_KEY = userdata.get('API_KEY')

client = Groq(api_key=API_KEY)

conversation_history = []

print("=" * 40)
print("   🤖 AI Chatbot powered by Groq")
print("   Ask me ANYTHING! Type 'quit' to exit")
print("=" * 40)

while True:
    user_input = input("\nYou: ").strip()

    if not user_input:
        print("Please type something!")
        continue

    if user_input.lower() == "quit":
        print("Goodbye! have a great day👋")
        break

    conversation_history.append({
        "role": "user",
        "content": user_input
    })

    try:
        response = client.chat.completions.create(
            model="llama-3.3-70b-versatile",   # ✅ updated model
            messages=conversation_history
        )

        bot_reply = response.choices[0].message.content

        conversation_history.append({

            "role": "assistant",
            "content": bot_reply
        })

        print(f"\nBot: {bot_reply}")

    except Exception as e:
        print(f"Something went wrong: {e}")
# Out:
# ...
#    🤖 AI Chatbot powered by Groq
#    Ask me ANYTHING! Type 'quit' to exit
# ...
#
# You: what is Python?
#
# Bot: **Python Overview**
# ...
#
# Python is a:
#
# * **High-level programming language**: Python is a language that abstracts away many low-level details, allowing developers to focus on the logic of their code.
# * **Interpreted language**: Python code is executed line by line, rather than compiled all at once.
# * **Multi-paradigm language**: Python supports object-oriented, imperative, and functional programming styles.
# * **Open-source language**: Python is free to use, modify, and distribute.
#
# **Key Features of Python**
# ------------------------
#
# * **Easy to learn**: Python has a simple syntax and is often taught as a first language to new programmers.
# * **Versatile**: Python can be used for web development, data analysis, machine learning, automation, and more.
# * **Large community**: Python has a vast and active community, with many libraries and frameworks available.
# ...
